# %%
## PDF probability Distribution Function/ Probability Distribution Function

# %%
data= [23,24,32,45,12,43,67,45,32,56,32]

# %%
data
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
import seaborn as sns

# %%
sns.histplot(data)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
data_copy= data.copy()

# %%
data_copy
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
data_copy.sort()

# %%
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67]

# %%
data_copy.append(179)

# %%
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67, 179]

# %%
data_copy.append(210)

# %%
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67, 179, 210]

# %%
data_copy.append(289)

# %%
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67, 179, 210, 289]

# %%
data_copy2 = data.copy()

# %%
data_copy2
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
data_copy2[0]= -10

# %%
data_copy2[1]= -75

# %%
data_copy2
# Out:
# [-10, -75, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
## KDE kernal density estimation

# %%
sns.histplot(data)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.histplot(data, kde= True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.histplot(data_copy)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.histplot(data_copy, kde= True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
## with the outlires the data is right skewed

# %%
sns.histplot(data_copy2)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.histplot(data_copy2, kde= True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
## with the outlires the data is left skewed

# %%
import pandas as pd
data2= pd.read_csv("https://raw.githubusercontent.com/sunnysavita10/Statistics-With-Python-TheCompleteGuide/main/Iris.csv")

# %%
data2
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
sns.histplot(data2["SepalLengthCm"], kde= True)
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='Count'>

# %%
## convert it to normal distribution

# %%
sns.histplot(np.log(data2["SepalLengthCm"]), kde= True)
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='Count'>

# %%
## we are not able to get the bell shaped curve which means data is not converted to normal distribution after 
##converting

# %%
sns.histplot(data2["SepalWidthCm"], kde= True)
# Out:
# <AxesSubplot:xlabel='SepalWidthCm', ylabel='Count'>

# %%
sns.histplot(data2["PetalLengthCm"], kde= True)
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='Count'>

# %%
sns.histplot(data2["PetalWidthCm"], kde= True)
# Out:
# <AxesSubplot:xlabel='PetalWidthCm', ylabel='Count'>

# %%
import numpy as np

# %%
nor= np.random.normal(0.5,0.2,1000)

# %%
nor
# Out:
# array([ 4.87632762e-01,  3.43872863e-01, -5.06939928e-02,  3.00548079e-01,
#         6.68351640e-01,  5.66321321e-01,  8.31053356e-01, -7.38691122e-02,
#         2.64888914e-01,  2.82717172e-01,  3.27623728e-01,  2.66124773e-01,
#         7.23793628e-01,  4.93104087e-01,  6.11426868e-01,  6.72455300e-01,
#         6.60241904e-01,  7.50233220e-01,  5.43042510e-01,  5.51067006e-01,
#         3.65466894e-01,  5.97194522e-01,  2.41019810e-01, -1.14935768e-01,
#         7.28629887e-01,  4.02061478e-01,  3.29992493e-01,  6.72578862e-01,
#         3.15278379e-01,  5.69728253e-01,  6.37816517e-01,  4.71018806e-01,
#         2.79244488e-01,  6.37886782e-01,  7.37919866e-01,  4.32021487e-01,
#         3.66709977e-01,  8.87415744e-01,  6.18105492e-01,  5.18342584e-01,
#         4.30950726e-01,  4.54404214e-01,  6.05549845e-01,  6.95565424e-01,
#         5.03676199e-01,  5.12309233e-01,  4.44758851e-01,  8.86962095e-01,
# ...

# %%
sns.histplot(nor,kde = True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
mu,sigma = 3.0,1.0
p= np.random.lognormal(mu,sigma,1000)

# %%
sns.histplot(p,kde = True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
## log normal distribution right skewed

# %%
p
# Out:
# array([ 21.58749002,   1.71633273,  16.6196772 ,  15.0705355 ,
#         30.46419101,  57.92164508,  16.1559445 ,  16.64224241,
#         27.96929904,  23.32037306,  21.73572935,  20.97524914,
#         54.69069551,   7.245973  ,  39.63437611,  20.6963054 ,
#          5.96293684,  11.38980764,  12.37972195,  71.67447522,
#         27.70192729,  12.60431701,  58.14889615,   1.88114652,
#         27.06521665,   3.23768145,  29.33665618,   5.85553757,
#         34.90566023,   8.50010644,  57.20717455,  21.39348036,
#         13.28671469,  27.6543971 ,  15.78918048,   4.06815356,
#          5.53000989,  59.10804072,  95.37394152, 181.25086068,
#         96.66505913,   6.25655094,   4.3472905 ,  41.91941436,
#         70.78480563,  14.69484718,  24.2350216 ,  18.0153493 ,
#          9.47967489,  14.25305758,  36.51424796,  24.81613064,
#         28.45825885,   7.23716784,  26.18291341,  11.45994319,
#         30.96794818,  11.70039055,  16.62336609,  27.88568334,
# ...

# %%
sns.histplot(np.log(p),kde = True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
## Technique to convert data into normal distribution
#Log Transformation
#Square-Root Transformation
#Reciprocal Transformation
#Box-Cox Transformation

# %%
## QQ plot Quantile-Quantile plot

# %%
import matplotlib.pyplot as plt
import scipy.stats as stat
import pylab
def plot_data(sample):
    plt.figure(figsize=(10,6))
    plt.subplot(1,2,1)
    sns.histplot(sample)
    plt.subplot(1,2,2)
    stat.probplot(sample,dist='norm',plot=pylab)
    plt.show

# %%
plot_data(data)

# %%
plot_data(data_copy)

# %%
import matplotlib.pyplot as plt
import scipy.stats as stat
import pylab
def plot_data(sample):
    plt.figure(figsize=(10,6))
    plt.subplot(1,2,1)
    sns.histplot(sample,kde=True)
    plt.subplot(1,2,2)
    stat.probplot(sample,dist='norm',plot=pylab)
    plt.show

# %%
plot_data(data)

# %%
plot_data(data_copy)

# %%
plot_data(nor)

# %%
plot_data(p)

# %%
plot_data(np.log(p))
